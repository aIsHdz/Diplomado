# %% [markdown]
# <a href="https://colab.research.google.com/github/aIsHdz/Diplomado/blob/main/Notas%20/%20Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame().dtypes
# Out:
# Series([], dtype: object)

# %%
data = [1, 2, 3, 4, 5]

pd.DataFrame(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd.DataFrame(data, columns=['Numeros'])
# Out:
#    Numeros
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
pd.DataFrame(data, columns=['Numeros'], index=['Lun','Mar','Mier','Juev','Vier'])
# Out:
#       Numeros
# Lun         1
# Mar         2
# Mier        3
# Juev        4
# Vier        5

# %%
data = [['Juan',20],['Luisa',30],['Ricardo',25]]

pd.DataFrame(data, columns=['Nombre','Edad'])
# Out:
#     Nombre  Edad
# 0     Juan    20
# 1    Luisa    30
# 2  Ricardo    25

# %%
#Otra forma de escribir un Data Frame
data = {'Nombre':['Juan','Luisa','Ricardo'],
        'Edad':[20,30,25],
        'Sexo':['H','M','H']}
pd.DataFrame(data)
# Out:
#     Nombre  Edad Sexo
# 0     Juan    20    H
# 1    Luisa    30    M
# 2  Ricardo    25    H

# %%
pd.read_excel('/content/tote_shipment.xlsx')
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
from google.colab import drive

# %%
#Conectar nuestro dirve a Google Colab
drive.mount('/content/drive')

# %cd /content/drive/My \Drive/NombreDelaCarpeta
#%cd /content/drive/MyDrive/NombreDelaCarpeta   <- Es lo mismo que el renglón de arriba

# %%
df = pd.read_excel('/content/tote_shipment.xlsx')
#Para el caso de que se utilice el archivo de Drive
#df = pd.read_excel('tote_sipment.xlsx')
df.head() #Muestra los primeros 5 valores en principio, df.head(n) para que te ponga n valores
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# ...

# %%
df.tail() #Muestra los últimos 5 valores en principio, df.tail(n) para que te ponga n valores
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 130056 -65.64101           23.1          73.58
# ...

# %%
df1 = pd.read_excel('/content/tote_shipment.xlsx', header = None) #Quitarle los encabezados a las columnas

df1.head()
# Out:
#            0         1                                2     3   \
# 0  asset_type  asset_id                           tag_id  Site
# 1        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 2        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 3        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 4        tote         2  (01)00850027865010(21)0082T0219  DC 1
#
#                4             5                           6         7   \
# 0            Zone     device_id                    time_est       lat
# 1  dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2  dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3  dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4  dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
#
#          8              9              10
# 0       lng  Temperature_C  Temperature_F
# 1 -65.68902             23           73.4
# ...

# %%
df1.columns = ['Tipo', 'Asset ID', 'Tag ID', 'Sitio', 'Zona', 'Device ID', 'Tiempo', 'lat', 'lng', 'Temp_C', 'Temp_F'] #cambiar el nombre de las columnas
df1
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# ...

# %%
df.columns #da el nombre de las columnas del Data Frame
# Out:
# Index(['asset_type', 'asset_id', 'tag_id', 'Site', 'Zone', 'device_id',
#        'time_est', 'lat', 'lng', 'Temperature_C', 'Temperature_F'],
#       dtype='object')

# %%
df = df.rename(columns = {'asset_type':'tipo', 'Site':'sitio', 'Zone':'zona', 'time_set':'hora'}) #cambiar el nombre de una columna o columnas en específico
df.head()
# Out:
#    tipo  asset_id                           tag_id sitio            zona  \
# 0  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4  tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# 1           73.4
# 2           73.4
# ...

# %%
df.shape #da el número de filas y columnas
# Out:
# (130061, 11)

# %%
df.info() #información del Data Frame xd
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tipo           130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   sitio          130061 non-null  object
#  4   zona           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
df.describe()
# Out:
#             asset_id            lat            lng  Temperature_C  \
# count  130061.000000  130061.000000  130061.000000  130061.000000
# mean      105.184475      47.760258     -65.668955      25.874445
# std        61.459262       0.019223       0.049597       2.795208
# min         2.000000      47.748780     -65.762200      19.000000
# 25%        58.000000      47.749230     -65.641010      24.000000
# 50%        84.000000      47.749230     -65.641010      25.000000
# 75%       167.000000      47.749388     -65.641010      27.500000
# max       205.000000      47.805010     -65.640330      44.000000
#
#        Temperature_F
# count  130061.000000
# mean       78.574000
# std         5.031375
# min        66.200000
# 25%        75.200000
# 50%        77.000000
# 75%        81.500000
# max       111.200000

# %%
df.describe(include= 'all')
# Out:
# <ipython-input-27-e4fb93151184>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include= 'all')
#           tipo       asset_id                           tag_id   sitio  \
# count   130061  130061.000000                           130061  130061
# unique       1            NaN                               34       4
# top       tote            NaN  (01)00850027865010(21)0082T0953   Store
# freq    130061            NaN                             6602   96897
# first      NaN            NaN                              NaN     NaN
# last       NaN            NaN                              NaN     NaN
# mean       NaN     105.184475                              NaN     NaN
# std        NaN      61.459262                              NaN     NaN
# ...

# %%
df['asset_id']
# Out:
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
#          ...
# 130056    205
# 130057    205
# 130058    205
# 130059    205
# 130060    205
# Name: asset_id, Length: 130061, dtype: int64

# %%
df[['asset_id','tag_id']]
# Out:
#         asset_id                           tag_id
# 0              2  (01)00850027865010(21)0082T0219
# 1              2  (01)00850027865010(21)0082T0219
# 2              2  (01)00850027865010(21)0082T0219
# 3              2  (01)00850027865010(21)0082T0219
# 4              2  (01)00850027865010(21)0082T0670
# ...          ...                              ...
# 130056       205  (01)00850027865010(21)0082T1137
# 130057       205  (01)00850027865010(21)0082T1137
# 130058       205  (01)00850027865010(21)0082T1137
# 130059       205  (01)00850027865010(21)0082T1137
# 130060       205  (01)00850027865010(21)0082T1137
#
# [130061 rows x 2 columns]

# %%
df['asset_id'].unique() #Muestra los registros únicos
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df['asset_id'].nunique() #Cuantos registros únicos hay
# Out:
# 18

# %%
df.asset_id.unique() #Es otr forma de escribir la línea anterior
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df.asset_id.nunique()
# Out:
# 18

# %%
df.sitio.unique()
# Out:
# array(['DC 1', 'DC 2', 'Transit', 'Store'], dtype=object)

# %%
df.zona.unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
df.groupby(['asset_id']).nunique()
# Out:
#           tipo  tag_id  sitio  zona  device_id  time_est  lat  lng  \
# asset_id
# 2            1       2      4    13         28      6769   63   63
# 37           1       2      4    14         23     12830  189  232
# 52           1       2      3    12         21      6819   53   59
# 58           1       2      3    11         19      8829  129  158
# 59           1       2      4    14         27      8823  130  158
# 62           1       2      4    13         24     11796  203  257
# 70           1       1      4    14         32      4648  160  192
# 84           1       2      3    13         23      8304  126  159
# 102          1       2      4    14         29      8197  110  132
# 145          1       2      4    13         21      4055   75   77
# 149          1       2      4    14         25      6348   59   61
# 159          1       2      4    12         25      6606  130  135
# 167          1       2      4    13         20      6774  152  178
# ...

# %%
df.groupby(['asset_id'])['tag_id'].nunique()
# Out:
# asset_id
# 2      2
# 37     2
# 52     2
# 58     2
# 59     2
# 62     2
# 70     1
# 84     2
# 102    2
# 145    2
# 149    2
# 159    2
# 167    2
# 170    2
# 181    1
# 182    2
# 200    2
# 205    2
# Name: tag_id, dtype: int64

# %%
pd.DataFrame(df.groupby(['asset_id'])['tag_id'].nunique()) #En forma de Dta Frame para manejralo diferente
# Out:
#           tag_id
# asset_id
# 2              2
# 37             2
# 52             2
# 58             2
# 59             2
# 62             2
# 70             1
# 84             2
# 102            2
# 145            2
# 149            2
# 159            2
# 167            2
# 170            2
# 181            1
# 182            2
# 200            2
# 205            2

# %%
pd.DataFrame(df.groupby(['asset_id'])['tag_id'].nunique()).reset_index() #Para poder agregarle el índice
# Out:
#     asset_id  tag_id
# 0          2       2
# 1         37       2
# 2         52       2
# 3         58       2
# 4         59       2
# 5         62       2
# 6         70       1
# 7         84       2
# 8        102       2
# 9        145       2
# 10       149       2
# 11       159       2
# 12       167       2
# 13       170       2
# 14       181       1
# 15       182       2
# 16       200       2
# 17       205       2

# %%
pd.DataFrame(df.groupby(['sitio'])['zona'].nunique()).reset_index()
# Out:
#      sitio  zona
# 0     DC 1     5
# 1     DC 2     2
# 2    Store     4
# 3  Transit     4

# %%
import numpy as np
df1.loc[df1['Zona'].sample(frac=2000, replace=True).index, 'Zona'] = np.NaN
df1.loc[df1['Temp_C'].sample(frac=1800, replace=True).index, 'Temp_C'] = np.NaN
df1.loc[df1['Temp_F'].sample(frac=1800, replace=True).index, 'Temp_F'] = np.NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130062 entries, 0 to 130061
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Tipo       130062 non-null  object
#  1   Asset ID   130062 non-null  object
#  2   Tag ID     130062 non-null  object
#  3   Sitio      130062 non-null  object
#  4   Zona       0 non-null       object
#  5   Device ID  130062 non-null  object
#  6   Tiempo     130062 non-null  object
#  7   lat        130062 non-null  object
#  8   lng        130062 non-null  object
#  9   Temp_C     130062 non-null  object
#  10  Temp_F     130062 non-null  object
# dtypes: object(11)
# memory usage: 10.9+ MB

# %%
df2 = df1.fillna(0) #Rellena los valores vacíos
df2
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  Zona  \
# 0       asset_type  asset_id                           tag_id   Site     0
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1     0
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1     0
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1     0
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1     0
# ...            ...       ...                              ...    ...   ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store     0
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store     0
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store     0
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store     0
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store     0
#
# ...

# %%
df2 = df1.fillna('NA')
df2
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio Zona  \
# 0       asset_type  asset_id                           tag_id   Site   NA
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1   NA
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1   NA
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1   NA
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1   NA
# ...            ...       ...                              ...    ...  ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store   NA
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store   NA
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store   NA
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store   NA
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store   NA
#
#            Device ID                      Tiempo       lat       lng  \
# ...

# %%
df3 = df1.copy()
df3['Zona'] = df3.Zona.fillna('Na')
df3['Temp_C'] = df3.Temp_C.fillna(0)
df3['Temp_F'] = df3.Temp_F.fillna(df.Temperature_F.mean())
df3
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio Zona  \
# 0       asset_type  asset_id                           tag_id   Site   Na
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# ...            ...       ...                              ...    ...  ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store   Na
#
#            Device ID                      Tiempo       lat       lng  \
# ...

# %%
df3 = df1.copy()
df3['Zona'] = df3.Zona.fillna('Na')
df3['Temp_C'] = df3.Temp_C.fillna(0)
df3['Temp_F'] = df3.Temp_F.fillna(df.Temperature_F.sum())
df3
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio Zona  \
# 0       asset_type  asset_id                           tag_id   Site   Na
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1   Na
# ...            ...       ...                              ...    ...  ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store   Na
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store   Na
#
#            Device ID                      Tiempo       lat       lng  \
# ...

# %%
df1[~df1.Temp_C.isna()]
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio Zona  \
# 0       asset_type  asset_id                           tag_id   Site  NaN
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1  NaN
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1  NaN
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1  NaN
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1  NaN
# ...            ...       ...                              ...    ...  ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store  NaN
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store  NaN
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store  NaN
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store  NaN
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store  NaN
#
#            Device ID                      Tiempo       lat       lng  \
# ...

# %%
df4 = df1.dropna() #elimina toda la fila si esta tiene un Na
df4
# Out:
# Empty DataFrame
# Columns: [Tipo, Asset ID, Tag ID, Sitio, Zona, Device ID, Tiempo, lat, lng, Temp_C, Temp_F]
# Index: []

# %%
df5 = df1.dropna(subset = ['Zona']) #
df5
# Out:
# Empty DataFrame
# Columns: [Tipo, Asset ID, Tag ID, Sitio, Zona, Device ID, Tiempo, lat, lng, Temp_C, Temp_F]
# Index: []

# %%
df1.isnull().sum()
# Out:
# Tipo              0
# Asset ID          0
# Tag ID            0
# Sitio             0
# Zona         130062
# Device ID         0
# Tiempo            0
# lat               0
# lng               0
# Temp_C            0
# Temp_F            0
# dtype: int64

# %%
df2 = df[df.asset_id == 2] #Filtrar información por datos de columnas
df2
# Out:
#       tipo  asset_id                           tag_id  sitio  \
# 0     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4     tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...    ...       ...                              ...    ...
# 6764  tote         2  (01)00850027865010(21)0082T0670  Store
# 6765  tote         2  (01)00850027865010(21)0082T0670  Store
# 6766  tote         2  (01)00850027865010(21)0082T0670  Store
# 6767  tote         2  (01)00850027865010(21)0082T0670  Store
# 6768  tote         2  (01)00850027865010(21)0082T0670  Store
#
#                    zona     device_id                time_est        lat  \
# 0        dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.791580
# 1        dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.791580
# ...

# %%
df2.asset_id.nunique()
# Out:
# 1

# %%
df3 = df[df.asset_id.isin([2,70,205])] #Filtrar información por coincidencias en columnas
df3
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df3.asset_id.nunique()
# Out:
# 3

# %%
df3 = df[(df.asset_id.isin([2,70,205])) & (df.Temperature_C >= 24)] #Filtrar información por condicionales
df3
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 5       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 6       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 7       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 8       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 9       tote         2  (01)00850027865010(21)0082T0670   DC 2
# ...      ...       ...                              ...    ...
# 129959  tote       205  (01)00850027865010(21)0082T1136  Store
# 129960  tote       205  (01)00850027865010(21)0082T1136  Store
# 129961  tote       205  (01)00850027865010(21)0082T1136  Store
# 129962  tote       205  (01)00850027865010(21)0082T1136  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 5          dock_doors_DC2  379663A695EF 2022-08-03 13:22:09.038  47.79366
# ...

# %%
df3.asset_id.nunique()
# Out:
# 3

# %%
df3.Temperature_C.min()
# Out:
# 24.0

# %%
df3 = df[(df.sitio == 'Store') & (df.Temperature_F >= 76)] #Filtrar información por condicionales
df3
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 241     tote         2  (01)00850027865010(21)0082T0219  Store
# 253     tote         2  (01)00850027865010(21)0082T0219  Store
# 254     tote         2  (01)00850027865010(21)0082T0219  Store
# 255     tote         2  (01)00850027865010(21)0082T0219  Store
# 256     tote         2  (01)00850027865010(21)0082T0219  Store
# ...      ...       ...                              ...    ...
# 129516  tote       205  (01)00850027865010(21)0082T1137  Store
# 129517  tote       205  (01)00850027865010(21)0082T1137  Store
# 129518  tote       205  (01)00850027865010(21)0082T1137  Store
# 129519  tote       205  (01)00850027865010(21)0082T1137  Store
# 129935  tote       205  (01)00850027865010(21)0082T1136  Store
#
#                        zona     device_id                time_est       lat  \
# 241     point_of_sale_Store  EEEB01ADE266 2022-08-04 10:58:04.546  47.74923
# ...

# %%
df3.sitio.nunique()
# Out:
# 1

# %%
df3 = df[(df.Temperature_F >= 76) & (df.Temperature_F <= 80)] #Filtrar información por condicionales
df3
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 5       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 6       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 7       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 8       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 9       tote         2  (01)00850027865010(21)0082T0670   DC 2
# ...      ...       ...                              ...    ...
# 128787  tote       205  (01)00850027865010(21)0082T1136  Store
# 128788  tote       205  (01)00850027865010(21)0082T1136  Store
# 128789  tote       205  (01)00850027865010(21)0082T1136  Store
# 128790  tote       205  (01)00850027865010(21)0082T1136  Store
# 129935  tote       205  (01)00850027865010(21)0082T1136  Store
#
#                      zona     device_id                time_est        lat  \
# 5          dock_doors_DC2  379663A695EF 2022-08-03 13:22:09.038  47.793660
# ...

# %%
df = df.drop(columns = ['Temperature_F'])
df
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df['Temperature_F'] = 0
df
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df['Temperature_F'] = 'NA'
df
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df['Temperature_F'] = df['Temperature_C'] + 9/5 + 32
df
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df1 = df[df.sitio == 'DC 1'].copy()
df1['Sitio_1'] = df1['zona'].str.split(pat = '_')
df1
# Out:
#         tipo  asset_id                           tag_id sitio            zona  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
# ...      ...       ...                              ...   ...             ...
# 126896  tote       205  (01)00850027865010(21)0082T1136  DC 1     staging_DC1
# 126897  tote       205  (01)00850027865010(21)0082T1137  DC 1     staging_DC1
# 126898  tote       205  (01)00850027865010(21)0082T1137  DC 1     staging_DC1
# 126899  tote       205  (01)00850027865010(21)0082T1137  DC 1     staging_DC1
# 126900  tote       205  (01)00850027865010(21)0082T1137  DC 1     staging_DC1
#
# ...

# %%
from datetime import datetime, date

# %%
df.groupby(['time_est']).asset_id.nunique()
# Out:
# time_est
# 2022-08-02 10:14:54.326    1
# 2022-08-02 10:15:38.860    1
# 2022-08-02 10:17:23.366    1
# 2022-08-02 10:18:23.847    1
# 2022-08-02 10:20:43.706    1
#                           ..
# 2022-08-05 13:28:26.584    1
# 2022-08-05 13:28:27.564    1
# 2022-08-05 13:28:28.172    1
# 2022-08-05 13:28:28.576    1
# 2022-08-05 13:28:29.966    1
# Name: asset_id, Length: 129887, dtype: int64

# %%
df['Fecha'] = pd.to_datetime(df.time_est).dt.date
df
# Out:
#         tipo  asset_id                           tag_id  sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df.groupby(['Fecha']).asset_id.nunique()
# Out:
# Fecha
# 2022-08-02    18
# 2022-08-03    13
# 2022-08-04    18
# 2022-08-05    18
# Name: asset_id, dtype: int64

# %%
df.groupby(['Fecha', 'sitio']).asset_id.nunique()
# Out:
# Fecha       sitio
# 2022-08-02  DC 1       18
#             DC 2        5
#             Transit    18
# 2022-08-03  DC 2        8
#             Transit    10
# 2022-08-04  DC 2       11
#             Store      18
#             Transit    18
# 2022-08-05  Store      18
# Name: asset_id, dtype: int64

# %%
df.groupby(['Fecha', 'sitio', 'zona']).asset_id.nunique()
# Out:
# Fecha       sitio    zona
# 2022-08-02  DC 1     Forklift1_DC1          14
#                      Forklift3_DC1          17
#                      dock_doors_DC1         16
#                      pallet_assembly_DC1    16
#                      staging_DC1            18
#             DC 2     dock_doors_DC2          3
#                      staging_DC2             4
#             Transit  PhoneKit1Bridge        18
#                      PhoneKit2Bridge        18
#                      PhoneKit2GW            18
# 2022-08-03  DC 2     dock_doors_DC2          8
#                      staging_DC2             2
#             Transit  PhoneKit1Bridge        10
#                      PhoneKit1GW             6
#                      PhoneKit2Bridge        10
#                      PhoneKit2GW            10
# 2022-08-04  DC 2     dock_doors_DC2          9
#                      staging_DC2             6
#             Store    point_of_sale_Store    12
# ...

# %%
df.groupby(['Fecha', 'sitio','zona', 'asset_id']).asset_id.nunique()
# Out:
# Fecha       sitio  zona               asset_id
# 2022-08-02  DC 1   Forklift1_DC1      37          1
#                                       52          1
#                                       59          1
#                                       62          1
#                                       70          1
#                                                  ..
# 2022-08-05  Store  store_front_Store  159         1
#                                       167         1
#                                       170         1
#                                       181         1
#                                       200         1
# Name: asset_id, Length: 385, dtype: int64

# %%
df.groupby(['Fecha', 'sitio', 'asset_id']).agg(temp_min = ('Temperature_C', 'min'), temp_max = ('Temperature_C', 'max'))
# Out:
#                            temp_min  temp_max
# Fecha      sitio asset_id
# 2022-08-02 DC 1  2            22.50     24.50
#                  37           22.50     23.00
#                  52           22.50     23.00
#                  58           22.50     24.00
#                  59           22.50     23.50
# ...                             ...       ...
# 2022-08-05 Store 170          24.00     29.50
#                  181          23.50     27.83
#                  182          20.25     31.00
#                  200          24.00     41.50
#                  205          20.50     25.00
#
# [124 rows x 2 columns]

# %%
#Armar un análisis de la base de datos
#Qué es, para qué sirve,
